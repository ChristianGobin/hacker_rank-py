# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
index = pd.date_range("1/1/2000", periods=8)
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
df = pd.DataFrame(np.random.randn(8, 3), index=index, columns=["A", "B", "C"])

# %%
print(s)
# Out:
# a   -1.631835
# b    0.149488
# c   -0.030460
# d   -2.507212
# e    0.687563
# dtype: float64

# %%
print(df)
# Out:
#                    A         B         C
# 2000-01-01 -0.304287  0.301141  0.496385
# 2000-01-02  0.158690 -0.449633 -0.849164
# 2000-01-03  0.633477  1.141691 -0.818492
# 2000-01-04  1.615114  0.279638  1.020267
# 2000-01-05 -0.849888  1.137062 -1.378969
# 2000-01-06  0.169196 -0.764033 -0.888724
# 2000-01-07 -0.463639  0.322544 -0.350908
# 2000-01-08 -0.447992 -0.342315 -0.957856

# %%
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1,2,3,4], [1,2,3,4])  # Plot some data on the axes.
